# %% [markdown]
# **PANDAS LIBRARY**

# %%
import pandas as pd

# %% [markdown]
# ***READING CSV FILE***

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#head function is used to print the starting elements
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#tail is used to view last data
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#to get the datatype we use dtype function
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#min max count std mean 25% 50% 75% max of data is found using describe func.
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes == 'float64'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
#to index of any datatype 
df[df.dtypes[df.dtypes=='float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %%
#slcing in column 
df[['Ticket']][4:16]
# Out:
#        Ticket
# 4      373450
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
df[['Ticket','Fare']][4:16:2]
#here 2 is step/jump
# Out:
#        Ticket     Fare
# 4      373450   8.0500
# 6       17463  51.8625
# 8      347742  11.1333
# 10    PP 9549  16.7000
# 12  A/5. 2151   8.0500
# 14     350406   7.8542

# %%
#creating new column in data
df['luggage']=2
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ***INSERTING COLUMN  IN BETWEEN OF DATAFRAME***

# %%
#we can insert column in btw of data using insert func
df.insert(loc=3,column='Food',value='Veg')
df
# Out:
#      PassengerId  Survived  Pclass Food  \
# 0              1         0       3  Veg
# 1              2         1       1  Veg
# 2              3         1       3  Veg
# 3              4         1       1  Veg
# 4              5         0       3  Veg
# ..           ...       ...     ...  ...
# 886          887         0       2  Veg
# 887          888         1       1  Veg
# 888          889         0       3  Veg
# 889          890         1       1  Veg
# 890          891         0       3  Veg
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Food', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'luggage'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#using slicing concept
df['Name'][0:11]
# Out:
# 0                               Braund, Mr. Owen Harris
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                Heikkinen, Miss. Laina
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                              Allen, Mr. William Henry
# 5                                      Moran, Mr. James
# 6                               McCarthy, Mr. Timothy J
# 7                        Palsson, Master. Gosta Leonard
# 8     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                   Nasser, Mrs. Nicholas (Adele Achem)
# 10                      Sandstrom, Miss. Marguerite Rut
# Name: Name, dtype: object

# %%
#using head concept
a=df['Name'].head(10)

# %%
a
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ***PANDAS SERIES***

# %%
#reindexing the df 
l=['a1','a2','a3','a4','a5','a6','a7','a8','a9','a10']
pd.Series(a,index=l)
# Out:
# a1     NaN
# a2     NaN
# a3     NaN
# a4     NaN
# a5     NaN
# a6     NaN
# a7     NaN
# a8     NaN
# a9     NaN
# a10    NaN
# Name: Name, dtype: object

# %%
#to prints the value of names present in data with indexes named in list 
pd.Series(list(a),index=l)
# Out:
# a1                               Braund, Mr. Owen Harris
# a2     Cumings, Mrs. John Bradley (Florence Briggs Th...
# a3                                Heikkinen, Miss. Laina
# a4          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# a5                              Allen, Mr. William Henry
# a6                                      Moran, Mr. James
# a7                               McCarthy, Mr. Timothy J
# a8                        Palsson, Master. Gosta Leonard
# a9     Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# a10                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
m1=pd.Series([100,200,300,400,500],index=[1,2,3,4,5])
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2=pd.Series([600,700,800,900,1000],index=[1,2,3,4,5])
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
#concatinating 2 df 
m3=pd.concat([m1,m2])
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1]#2 input for one index are avalaible
# Out:
# 1    100
# 1    600
# dtype: int64

# %%
m1*m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %%
#there is difference in concatination and addition
#In addition it will add the values present at same index
#where as in concatination it will merge both the dataframes
m1+m2
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass Food  \
# 0            1         0       3  Veg
# 1            2         1       1  Veg
# 2            3         1       3  Veg
# 3            4         1       1  Veg
# 4            5         0       3  Veg
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  luggage
# 0      0         A/5 21171   7.2500   NaN        S        2
# 1      0          PC 17599  71.2833   C85        C        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        2
# ...

# %% [markdown]
# ***DELETING THE ROWS AND COLUMN IN DATAFRAME PERMANENTLY***

# %%
#How to delete a column
#column have axis 1
#rows have axis 0
#this drop function deletes the column or row tempararily not permanently
df.drop(['Food','luggage'],axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#to check whether the deleted rows are deleted permanently 
df.head()
# Out:
#    PassengerId  Survived  Pclass Food  \
# 0            1         0       3  Veg
# 1            2         1       1  Veg
# 2            3         1       3  Veg
# 3            4         1       1  Veg
# 4            5         0       3  Veg
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  luggage
# 0      0         A/5 21171   7.2500   NaN        S        2
# 1      0          PC 17599  71.2833   C85        C        2
# 2      0  STON/O2. 3101282   7.9250   NaN        S        2
# ...

# %%
df.columns
#the columns are deleted permanently
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Food', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'luggage'],
#       dtype='object')

# %%
df.drop(5)
# Out:
#      PassengerId  Survived  Pclass Food  \
# 0              1         0       3  Veg
# 1              2         1       1  Veg
# 2              3         1       3  Veg
# 3              4         1       1  Veg
# 4              5         0       3  Veg
# ..           ...       ...     ...  ...
# 886          887         0       2  Veg
# 887          888         1       1  Veg
# 888          889         0       3  Veg
# 889          890         1       1  Veg
# 890          891         0       3  Veg
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# ***SETTING AND RESETTING INDEX IN DATAFRAME***

# %%
#How to change the default index for the dataframe by replacing it with column
df.set_index('Name',inplace=True)
#the name row will now be our index for the dataframe 
#set_index() method is used to set the index of data frame with the column present in dataframe.

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
#how to reset the index for the dataframe
df.reset_index()
#this will reset the changes made using set_index() function
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %% [markdown]
# ***READING DICTIONARY TO DATAFRAME***

# %%
#task:using dictionary create dataframe
#d={"k1":[1,2,3,4,5],"k2":[3,4,5,6,7],"k3":[6,7,8,9,10]}----> dataframe
d={"key1":[1,2,3,4,5],"key2":[6,7,8,9,10],"key3":[11,12,13,14,15]}
print(d)
# Out:
# {'key1': [1, 2, 3, 4, 5], 'key2': [6, 7, 8, 9, 10], 'key3': [11, 12, 13, 14, 15]}

# %%
#converting dictionary to dataframe
#DataFrame() method is used to convert the dictionary to dataframe
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %% [markdown]
# ***DELETING THE ROWS AND COLUMNS CONTAINING NaN IN DATAFRAME***

# %%
df1=pd.read_csv(r"C:\Users\HP\Downloads\nucc_taxonomy_240.csv")
df1
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# ...

# %%
#deleting the rows containing NaN
df1.dropna(inplace=True)
#important for cleaning data

# %%
df1
# Out:
#            Code                             Grouping  \
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# 6    207LA0401X  Allopathic & Osteopathic Physicians
# 7    207LC0200X  Allopathic & Osteopathic Physicians
# 8    207LH0002X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 860  3416L0300X              Transportation Services
# 861  3416S0300X              Transportation Services
# 864  3418M1120X              Transportation Services
# 865  3418M1110X              Transportation Services
# 866  3418M1130X              Transportation Services
#
#                           Classification  \
# 3                   Allergy & Immunology
# 4                   Allergy & Immunology
# 6                         Anesthesiology
# 7                         Anesthesiology
# 8                         Anesthesiology
# ..                                   ...
# ...

# %%
df2=pd.read_csv(r"C:\Users\HP\Downloads\nucc_taxonomy_240.csv")
df2
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# ...

# %%
#deleting columns having nan
df2.dropna(axis=1)
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification  \
# 0                    Multi-Specialty
# 1                   Single Specialty
# 2               Allergy & Immunology
# 3               Allergy & Immunology
# 4               Allergy & Immunology
# ..                               ...
# 869  Secured Medical Transport (VAN)
# ...

# %%
df2
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# ...

# %%
df3=pd.read_csv(r"C:\Users\HP\Downloads\nucc_taxonomy_240.csv")
df3
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               NaN
# 1                   Single Specialty                               NaN
# 2               Allergy & Immunology                               NaN
# ...

# %%
#replacing NaN present in data 
df3.fillna("XYZ",inplace=True)

# %%
df3
# Out:
#            Code                             Grouping  \
# 0    193200000X                                Group
# 1    193400000X                                Group
# 2    207K00000X  Allopathic & Osteopathic Physicians
# 3    207KA0200X  Allopathic & Osteopathic Physicians
# 4    207KI0005X  Allopathic & Osteopathic Physicians
# ..          ...                                  ...
# 869  343800000X              Transportation Services
# 870  344600000X              Transportation Services
# 871  347D00000X              Transportation Services
# 872  347E00000X              Transportation Services
# 873  342000000X              Transportation Services
#
#                       Classification                    Specialization  \
# 0                    Multi-Specialty                               XYZ
# 1                   Single Specialty                               XYZ
# 2               Allergy & Immunology                               XYZ
# ...

# %%
import matplotlib.pyplot as plt
df["Age"].plot(kind='hist')
plt.show()
